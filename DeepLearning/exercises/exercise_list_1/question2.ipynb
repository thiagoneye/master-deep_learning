# %% [markdown]
# ### Packages and Frameworks

# %%
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow_datasets as tfds

from tensorflow import keras

from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils.class_weight import compute_class_weight

from imblearn.over_sampling import SMOTE
from collections import Counter
# Out:
# 2025-09-02 11:32:19.688568: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-02 11:32:19.763669: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-02 11:32:20.930567: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# #### Auxiliary Functions

# %%
def sturges_bins(x):
    x = np.asarray(x)
    x = x[~np.isnan(x)]
    n = len(x)
    if n <= 1:
        return 1, np.inf

    k = math.ceil(math.log2(n)) + 1
    data_range = x.max() - x.min()
    h = data_range / k if data_range > 0 else np.inf
    h = math.ceil(h)
    
    return k, h

# %% [markdown]
# ### Questão 2
#
# O conjunto de dados Wine  Quality  Dataset contém medições físico-químicas de vinhos (como acidez, teor alcoólico e pH) e uma nota de qualidade atribuída por especialistas. Esse problema é amplamente utilizado para estudo de classificação supervisionada, pois envolve a
# relação entre variáveis químicas e uma avaliação subjetiva de qualidade. Aplique as técnicas de pré-processamento de dados vistas em salas de aula. Em seguida, divida os dados em conjuntos  de  treinamento  e  de  teste,  e  implemente  e  treine  uma  Rede  Perceptron  de
# Múltiplas Camadas (MLP) para classificar a qualidade de vinhos.
#
# Apresente  também  as  curvas  de  erro  de  treinamento  e  validação,  e  calcule  a  matriz  de confusão.
#
# Algumas recomendações:
# * Verifique a existência de valores ausentes ou inconsistentes e trate-os adequadamente.
# * Analise  a distribuição da variável-alvo e verifique se há desbalanceamento entre as classes.
# * Calcule correlações entre atributos e o rótulo de qualidade, removendo ou mantendo atributos com base nessa análise.
# * Aplique normalização ou padronização das variáveis numéricas, justificando a escolha.
# * Registre e compare estatísticas antes e depois do pré-processamento.

# %% [markdown]
# #### Data Reading

# %%
ds_red = tfds.load("wine_quality/red", split="train", as_supervised=False)
ds_white = tfds.load("wine_quality/white", split="train", as_supervised=False)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1756823546.522031   33519 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# #### Data Processing

# %%
df_red = tfds.as_dataframe(ds_red)
df_white = tfds.as_dataframe(ds_white)

df_red["type"] = "red"
df_white["type"] = "white"

df = pd.concat([df_red, df_white], ignore_index=True)

df.type = LabelEncoder().fit_transform(df.type)

min_quality = np.min(df.quality)
df.quality -= min_quality

for column_name in df.columns:
    new_name = column_name.replace("features/", "")
    df.rename(columns={column_name: new_name}, inplace=True)

display(df.head())
display(df.info())
display(df.describe())
# Out:
# 2025-09-02 11:32:28.615041: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:396] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 2025-09-02 11:32:28.984633: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-09-02 11:32:30.176304: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#    alcohol  chlorides  citric acid  density  fixed acidity  \
# 0    10.55      0.050         0.06  0.99236            6.0
# 1    11.60      0.086         0.31  1.00020            8.7
# 2    11.70      0.012         0.28  0.99064            6.7
# 3     9.50      0.078         0.24  0.99830            7.5
# 4     9.20      0.088         0.26  0.99810            7.8
#
#    free sulfur dioxide    pH  residual sugar  sulphates  total sulfur dioxide  \
# 0                 38.0  3.30             1.8       0.50                  89.0
# 1                 23.0  3.48             3.0       0.74                  81.0
# 2                 36.0  3.26             2.4       0.39                 100.0
# 3                 10.0  3.45             2.0       0.78                  28.0
# 4                 23.0  3.41             2.0       0.74                  48.0
#
#    volatile acidity  quality  type
# 0              0.54        3     0
# 1              0.69        3     0
# 2              0.28        4     0
# 3              0.55        3     0
# 4              0.54        3     0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alcohol               6497 non-null   float32
#  1   chlorides             6497 non-null   float32
#  2   citric acid           6497 non-null   float32
#  3   density               6497 non-null   float32
#  4   fixed acidity         6497 non-null   float32
#  5   free sulfur dioxide   6497 non-null   float32
#  6   pH                    6497 non-null   float32
#  7   residual sugar        6497 non-null   float32
#  8   sulphates             6497 non-null   float64
#  9   total sulfur dioxide  6497 non-null   float32
#  10  volatile acidity      6497 non-null   float32
#  11  quality               6497 non-null   int32
#  12  type                  6497 non-null   int64
# dtypes: float32(10), float64(1), int32(1), int64(1)
# memory usage: 380.8 KB
# None
#            alcohol    chlorides  citric acid      density  fixed acidity  \
# count  6497.000000  6497.000000  6497.000000  6497.000000    6497.000000
# mean     10.491801     0.056034     0.318633     0.994697       7.215307
# std       1.192711     0.035033     0.145319     0.002999       1.296448
# min       8.000000     0.009000     0.000000     0.987110       3.800000
# 25%       9.500000     0.038000     0.250000     0.992340       6.400000
# 50%      10.300000     0.047000     0.310000     0.994890       7.000000
# 75%      11.300000     0.065000     0.390000     0.996990       7.700000
# max      14.900000     0.611000     1.660000     1.038980      15.900000
#
#        free sulfur dioxide           pH  residual sugar    sulphates  \
# count          6497.000000  6497.000000     6497.000000  6497.000000
# mean             30.525320     3.218501        5.443235     0.531268
# std              17.749403     0.160786        4.757818     0.148806
# min               1.000000     2.720000        0.600000     0.220000
# 25%              17.000000     3.110000        1.800000     0.430000
# 50%              29.000000     3.210000        3.000000     0.510000
# 75%              41.000000     3.320000        8.100000     0.600000
# max             289.000000     4.010000       65.800003     2.000000
#
#        total sulfur dioxide  volatile acidity      quality         type
# count           6497.000000       6497.000000  6497.000000  6497.000000
# mean             115.744576          0.339666     2.818378     0.753886
# std               56.521889          0.164636     0.873255     0.430779
# min                6.000000          0.080000     0.000000     0.000000
# 25%               77.000000          0.230000     2.000000     1.000000
# 50%              118.000000          0.290000     3.000000     1.000000
# 75%              156.000000          0.400000     3.000000     1.000000
# max              440.000000          1.580000     6.000000     1.000000

# %%
# Counter Plot

order = df["quality"].value_counts().index

plt.figure()
ax = sns.countplot(data=df, x="quality", order=order)

for p in ax.patches:
    ax.annotate(
        f"{p.get_height():.0f}",
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="bottom",
        fontsize=10,
        color="black",
        xytext=(0, 5),
        textcoords="offset points",
    )

ax.yaxis.set_visible(False)
plt.ylim([0, 3250])
plt.xlabel("Classification")
plt.title("Wine Quality")
# Out:
# Text(0.5, 1.0, 'Wine Quality')

# %%
# Remove the Minority Class

# df = df[df.quality != 6]

# %%
# Plot of Histograms

fig, axes = plt.subplots(ncols=3, nrows=4, figsize=(12, 16))
axes = axes.flatten()

for idx, col in enumerate(df.columns):
    if col != "type":
        data = df[col].values
        k, _ = sturges_bins(data)

        sns.histplot(data=data, bins=k, kde=True, ax=axes[idx])
        axes[idx].set_title(f"{col.replace("features/", "")}")
        axes[idx].set_xlabel("")
        axes[idx].set_ylabel("")

# %%
# Correlation Matrix

corr_matrix = df.corr()
abs_corr_matrix = np.abs(corr_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(abs_corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlação (Valor Absolutos)")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlação")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()

# %% [markdown]
# #### Model

# %%
# Data

num_classes = len(df.quality.unique())

X = df.loc[:, df.columns[df.columns != "quality"]].values

y = df.loc[:, "quality"].values
# y = keras.utils.to_categorical(y, num_classes=num_classes)

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X_train, X_test_full, y_train, y_test_full = train_test_split(
    X_normalized, y, test_size=0.2, random_state=42
)
X_test, X_valid, y_test, y_valid = train_test_split(
    X_test_full, y_test_full, test_size=0.5, random_state=42
)

# %%
# smote = SMOTE(sampling_strategy="auto", random_state=42)

# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# print(pd.Series(y_train_resampled).value_counts())

# %%
# class_weights_array = compute_class_weight(
#     class_weight="balanced", classes=np.unique(y_train_resampled), y=y_train_resampled
# )
# class_weights_dict = dict(zip(np.unique(y_train_resampled), class_weights_array))

# print(class_weights_array)

# %%
# Model

# Building the Layers

input_ = keras.layers.Input(shape=X_train.shape[1:])

hidden1 = keras.layers.Dense(200, activation="relu")(input_)
dropout1 = keras.layers.Dropout(0.3)(hidden1)

hidden2 = keras.layers.Dense(100, activation="relu")(dropout1)
dropout2 = keras.layers.Dropout(0.3)(hidden2)

hidden3 = keras.layers.Dense(50, activation="relu")(dropout2)
dropout3 = keras.layers.Dropout(0.3)(hidden3)

output = keras.layers.Dense(num_classes, activation="softmax")(dropout3)

# Model Configuration

model = keras.Model(inputs=[input_], outputs=[output])

custom_optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    loss="sparse_categorical_crossentropy", optimizer=custom_optimizer, metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           357 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,107 (109.79 KB)
#  Trainable params: 28,107 (109.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    validation_data=(X_valid, y_valid),
    # class_weight=class_weights_dict,
)

# Prediction

y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4247 - loss: 1.3786 - val_accuracy: 0.4800 - val_loss: 1.1541
# Epoch 2/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4911 - loss: 1.1867 - val_accuracy: 0.5446 - val_loss: 1.1004
# Epoch 3/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5047 - loss: 1.1580 - val_accuracy: 0.5123 - val_loss: 1.1005
# Epoch 4/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5232 - loss: 1.1438 - val_accuracy: 0.5431 - val_loss: 1.0764
# Epoch 5/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5143 - loss: 1.1282 - val_accuracy: 0.5492 - val_loss: 1.0662
# Epoch 6/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5274 - loss: 1.1167 - val_accuracy: 0.5508 - val_loss: 1.0702
# Epoch 7/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5365 - loss: 1.1039 - val_accuracy: 0.5415 - val_loss: 1.0591
# Epoch 8/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5276 - loss: 1.1034 - val_accuracy: 0.5462 - val_loss: 1.0576
# Epoch 9/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5434 - loss: 1.0903 - val_accuracy: 0.5569 - val_loss: 1.0419
# Epoch 10/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5368 - loss: 1.0886 - val_accuracy: 0.5538 - val_loss: 1.0400
# Epoch 11/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5392 - loss: 1.0866 - val_accuracy: 0.5462 - val_loss: 1.0501
# Epoch 12/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5447 - loss: 1.0734 - val_accuracy: 0.5477 - val_loss: 1.0328
# Epoch 13/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5449 - loss: 1.0673 - val_accuracy: 0.5569 - val_loss: 1.0293
# Epoch 14/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5403 - loss: 1.0599 - val_accuracy: 0.5708 - val_loss: 1.0313
# Epoch 15/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5449 - loss: 1.0574 - val_accuracy: 0.5554 - val_loss: 1.0341
# Epoch 16/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5540 - loss: 1.0584 - val_accuracy: 0.5508 - val_loss: 1.0346
# Epoch 17/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5519 - loss: 1.0487 - val_accuracy: 0.5708 - val_loss: 1.0228
# Epoch 18/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5476 - loss: 1.0472 - val_accuracy: 0.5662 - val_loss: 1.0201
# Epoch 19/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5465 - loss: 1.0484 - val_accuracy: 0.5492 - val_loss: 1.0324
# Epoch 20/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5511 - loss: 1.0436 - val_accuracy: 0.5523 - val_loss: 1.0169
# Epoch 21/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5420 - loss: 1.0493 - val_accuracy: 0.5677 - val_loss: 1.0150
# Epoch 22/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5534 - loss: 1.0397 - val_accuracy: 0.5692 - val_loss: 1.0095
# Epoch 23/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5526 - loss: 1.0345 - val_accuracy: 0.5600 - val_loss: 1.0173
# Epoch 24/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5538 - loss: 1.0302 - val_accuracy: 0.5585 - val_loss: 1.0148
# Epoch 25/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5563 - loss: 1.0354 - val_accuracy: 0.5692 - val_loss: 1.0102
# Epoch 26/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5553 - loss: 1.0315 - val_accuracy: 0.5662 - val_loss: 1.0073
# Epoch 27/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5578 - loss: 1.0331 - val_accuracy: 0.5708 - val_loss: 1.0069
# Epoch 28/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5546 - loss: 1.0330 - val_accuracy: 0.5754 - val_loss: 1.0087
# Epoch 29/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5569 - loss: 1.0295 - val_accuracy: 0.5708 - val_loss: 0.9963
# Epoch 30/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5567 - loss: 1.0327 - val_accuracy: 0.5631 - val_loss: 1.0052
# Epoch 31/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5621 - loss: 1.0259 - val_accuracy: 0.5754 - val_loss: 1.0006
# Epoch 32/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5576 - loss: 1.0287 - val_accuracy: 0.5523 - val_loss: 1.0112
# Epoch 33/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5536 - loss: 1.0208 - val_accuracy: 0.5631 - val_loss: 0.9995
# Epoch 34/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ -1s -8264us/step - accuracy: 0.5574 - loss: 1.0211 - val_accuracy: 0.5677 - val_loss: 0.9941
# Epoch 35/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5609 - loss: 1.0227 - val_accuracy: 0.5769 - val_loss: 0.9963
# Epoch 36/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5628 - loss: 1.0213 - val_accuracy: 0.5677 - val_loss: 0.9981
# Epoch 37/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5590 - loss: 1.0211 - val_accuracy: 0.5723 - val_loss: 0.9963
# Epoch 38/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5626 - loss: 1.0123 - val_accuracy: 0.5800 - val_loss: 0.9946
# Epoch 39/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5592 - loss: 1.0155 - val_accuracy: 0.5738 - val_loss: 1.0045
# Epoch 40/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5605 - loss: 1.0226 - val_accuracy: 0.5862 - val_loss: 0.9877
# Epoch 41/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5619 - loss: 1.0126 - val_accuracy: 0.5877 - val_loss: 1.0047
# Epoch 42/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5588 - loss: 1.0154 - val_accuracy: 0.5738 - val_loss: 0.9936
# Epoch 43/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5663 - loss: 1.0072 - val_accuracy: 0.5646 - val_loss: 0.9949
# Epoch 44/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5622 - loss: 1.0017 - val_accuracy: 0.5708 - val_loss: 0.9944
# Epoch 45/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5613 - loss: 1.0102 - val_accuracy: 0.5877 - val_loss: 0.9882
# Epoch 46/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5653 - loss: 1.0070 - val_accuracy: 0.5692 - val_loss: 0.9976
# Epoch 47/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5632 - loss: 1.0078 - val_accuracy: 0.5615 - val_loss: 1.0053
# Epoch 48/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5613 - loss: 1.0073 - val_accuracy: 0.5692 - val_loss: 0.9941
# Epoch 49/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5619 - loss: 1.0052 - val_accuracy: 0.5677 - val_loss: 0.9874
# Epoch 50/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5607 - loss: 0.9964 - val_accuracy: 0.5708 - val_loss: 1.0036
# Epoch 51/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 1.0059 - val_accuracy: 0.5815 - val_loss: 0.9944
# Epoch 52/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5707 - loss: 1.0028 - val_accuracy: 0.5846 - val_loss: 0.9875
# Epoch 53/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5634 - loss: 0.9956 - val_accuracy: 0.5646 - val_loss: 0.9896
# Epoch 54/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5671 - loss: 0.9960 - val_accuracy: 0.5831 - val_loss: 0.9880
# Epoch 55/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5730 - loss: 0.9914 - val_accuracy: 0.5862 - val_loss: 0.9925
# Epoch 56/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5684 - loss: 0.9982 - val_accuracy: 0.5723 - val_loss: 0.9873
# Epoch 57/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5680 - loss: 0.9963 - val_accuracy: 0.5692 - val_loss: 0.9859
# Epoch 58/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5786 - loss: 0.9939 - val_accuracy: 0.5615 - val_loss: 0.9936
# Epoch 59/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5611 - loss: 0.9970 - val_accuracy: 0.5662 - val_loss: 0.9895
# Epoch 60/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.9902 - val_accuracy: 0.5615 - val_loss: 0.9917
# Epoch 61/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.9897 - val_accuracy: 0.5800 - val_loss: 0.9882
# Epoch 62/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5663 - loss: 1.0005 - val_accuracy: 0.5785 - val_loss: 0.9887
# Epoch 63/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5709 - loss: 0.9873 - val_accuracy: 0.5769 - val_loss: 0.9893
# Epoch 64/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5726 - loss: 0.9858 - val_accuracy: 0.5600 - val_loss: 0.9916
# Epoch 65/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5719 - loss: 0.9925 - val_accuracy: 0.5523 - val_loss: 1.0009
# Epoch 66/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5749 - loss: 0.9836 - val_accuracy: 0.5585 - val_loss: 0.9915
# Epoch 67/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5784 - loss: 0.9826 - val_accuracy: 0.5600 - val_loss: 1.0066
# Epoch 68/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5707 - loss: 0.9937 - val_accuracy: 0.5662 - val_loss: 0.9949
# Epoch 69/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5647 - loss: 0.9944 - val_accuracy: 0.5831 - val_loss: 0.9943
# Epoch 70/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5736 - loss: 0.9833 - val_accuracy: 0.5769 - val_loss: 0.9866
# Epoch 71/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5807 - loss: 0.9812 - val_accuracy: 0.5754 - val_loss: 0.9941
# Epoch 72/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5771 - loss: 0.9820 - val_accuracy: 0.5769 - val_loss: 0.9914
# Epoch 73/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5721 - loss: 0.9842 - val_accuracy: 0.5677 - val_loss: 0.9905
# Epoch 74/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5780 - loss: 0.9801 - val_accuracy: 0.5600 - val_loss: 0.9972
# Epoch 75/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5809 - loss: 0.9779 - val_accuracy: 0.5600 - val_loss: 0.9898
# Epoch 76/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5799 - loss: 0.9792 - val_accuracy: 0.5677 - val_loss: 0.9981
# Epoch 77/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5780 - loss: 0.9822 - val_accuracy: 0.5600 - val_loss: 0.9977
# Epoch 78/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5765 - loss: 0.9745 - val_accuracy: 0.5585 - val_loss: 0.9945
# Epoch 79/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5678 - loss: 0.9812 - val_accuracy: 0.5785 - val_loss: 0.9844
# Epoch 80/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 0.9770 - val_accuracy: 0.5708 - val_loss: 0.9876
# Epoch 81/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5819 - loss: 0.9680 - val_accuracy: 0.5815 - val_loss: 0.9813
# Epoch 82/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5799 - loss: 0.9730 - val_accuracy: 0.5738 - val_loss: 0.9940
# Epoch 83/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5784 - loss: 0.9730 - val_accuracy: 0.5754 - val_loss: 0.9834
# Epoch 84/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5792 - loss: 0.9736 - val_accuracy: 0.5831 - val_loss: 0.9864
# Epoch 85/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5799 - loss: 0.9734 - val_accuracy: 0.5708 - val_loss: 0.9888
# Epoch 86/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5832 - loss: 0.9613 - val_accuracy: 0.5508 - val_loss: 0.9934
# Epoch 87/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 0.9732 - val_accuracy: 0.5692 - val_loss: 0.9985
# Epoch 88/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5840 - loss: 0.9622 - val_accuracy: 0.5646 - val_loss: 0.9868
# Epoch 89/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5769 - loss: 0.9719 - val_accuracy: 0.5677 - val_loss: 0.9840
# Epoch 90/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5850 - loss: 0.9609 - val_accuracy: 0.5692 - val_loss: 0.9895
# Epoch 91/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5815 - loss: 0.9603 - val_accuracy: 0.5723 - val_loss: 0.9826
# Epoch 92/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5786 - loss: 0.9666 - val_accuracy: 0.5585 - val_loss: 0.9818
# Epoch 93/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5840 - loss: 0.9623 - val_accuracy: 0.5538 - val_loss: 0.9953
# Epoch 94/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5863 - loss: 0.9698 - val_accuracy: 0.5723 - val_loss: 0.9830
# Epoch 95/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5838 - loss: 0.9565 - val_accuracy: 0.5769 - val_loss: 0.9813
# Epoch 96/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5859 - loss: 0.9557 - val_accuracy: 0.5754 - val_loss: 0.9898
# Epoch 97/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5734 - loss: 0.9607 - val_accuracy: 0.5615 - val_loss: 0.9920
# Epoch 98/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5832 - loss: 0.9567 - val_accuracy: 0.5846 - val_loss: 0.9742
# Epoch 99/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5780 - loss: 0.9603 - val_accuracy: 0.5600 - val_loss: 0.9878
# Epoch 100/100
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5844 - loss: 0.9520 - val_accuracy: 0.5723 - val_loss: 0.9761
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Training Metrics

plt.figure()
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.title("Métricas de Treinamento")
plt.xlabel("Épocas")
plt.grid(True)
plt.show()

# %%
# Metrics

y_pred = np.argmax(y_pred, axis=1)

# Confusion Matrix

cm = confusion_matrix(y_true=y_test, y_pred=y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Valores Previstos")
plt.ylabel("Valores Verdadeiros")
plt.title("Matriz de Confusão")
plt.show()

# Accuracy

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print(f"Acurácia do modelo: {int(round(accuracy*100, 0))}%")
# Out:
# Acurácia do modelo: 59%
